# %%
import dask.dataframe as dd
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns

# %matplotlib inline

# %%
path = "/home/carlos/Dokument/data/pills/pills/pills.tsv"

# %%
df = dd.read_table(path, dtype={'ACTION_INDICATOR': 'object',
       'ORDER_FORM_NO': 'object',
       'REPORTER_ADDL_CO_INFO': 'object',
       'REPORTER_ADDRESS2': 'object'})

# %%
df.head()
# Out:
#   REPORTER_DEA_NO REPORTER_BUS_ACT               REPORTER_NAME  \
# 0       PA0006836      DISTRIBUTOR  ACE SURGICAL SUPPLY CO INC
# 1       PA0021179      DISTRIBUTOR                APOTHECA INC
# 2       PA0021179      DISTRIBUTOR                APOTHECA INC
# 3       PA0021179      DISTRIBUTOR                APOTHECA INC
# 4       PA0021179      DISTRIBUTOR                APOTHECA INC
#
#   REPORTER_ADDL_CO_INFO  REPORTER_ADDRESS1 REPORTER_ADDRESS2 REPORTER_CITY  \
# 0                   NaN  1034 PEARL STREET               NaN      BROCKTON
# 1                   NaN     1622 N 16TH ST               NaN       PHOENIX
# 2                   NaN     1622 N 16TH ST               NaN       PHOENIX
# 3                   NaN     1622 N 16TH ST               NaN       PHOENIX
# 4                   NaN     1622 N 16TH ST               NaN       PHOENIX
#
#   REPORTER_STATE  REPORTER_ZIP REPORTER_COUNTY  ... DOSAGE_UNIT  \
# 0             MA          2301        PLYMOUTH  ...       100.0
# ...

# %%
df.columns
# Out:
# Index(['REPORTER_DEA_NO', 'REPORTER_BUS_ACT', 'REPORTER_NAME',
#        'REPORTER_ADDL_CO_INFO', 'REPORTER_ADDRESS1', 'REPORTER_ADDRESS2',
#        'REPORTER_CITY', 'REPORTER_STATE', 'REPORTER_ZIP', 'REPORTER_COUNTY',
#        'BUYER_DEA_NO', 'BUYER_BUS_ACT', 'BUYER_NAME', 'BUYER_ADDL_CO_INFO',
#        'BUYER_ADDRESS1', 'BUYER_ADDRESS2', 'BUYER_CITY', 'BUYER_STATE',
#        'BUYER_ZIP', 'BUYER_COUNTY', 'TRANSACTION_CODE', 'DRUG_CODE', 'NDC_NO',
#        'DRUG_NAME', 'QUANTITY', 'UNIT', 'ACTION_INDICATOR', 'ORDER_FORM_NO',
#        'CORRECTION_NO', 'STRENGTH', 'TRANSACTION_DATE', 'CALC_BASE_WT_IN_GM',
#        'DOSAGE_UNIT', 'TRANSACTION_ID', 'Product_Name', 'Ingredient_Name',
#        'Measure', 'MME_Conversion_Factor', 'Combined_Labeler_Name',
#        'Revised_Company_Name', 'Reporter_family', 'dos_str'],
#       dtype='object')

# %%
df.dtypes
# Out:
# REPORTER_DEA_NO           object
# REPORTER_BUS_ACT          object
# REPORTER_NAME             object
# REPORTER_ADDL_CO_INFO     object
# REPORTER_ADDRESS1         object
# REPORTER_ADDRESS2         object
# REPORTER_CITY             object
# REPORTER_STATE            object
# REPORTER_ZIP               int64
# REPORTER_COUNTY           object
# BUYER_DEA_NO              object
# BUYER_BUS_ACT             object
# BUYER_NAME                object
# BUYER_ADDL_CO_INFO        object
# BUYER_ADDRESS1            object
# BUYER_ADDRESS2            object
# BUYER_CITY                object
# BUYER_STATE               object
# BUYER_ZIP                  int64
# BUYER_COUNTY              object
# TRANSACTION_CODE          object
# DRUG_CODE                  int64
# NDC_NO                     int64
# DRUG_NAME                 object
# QUANTITY                 float64
# UNIT                     float64
# ACTION_INDICATOR          object
# ORDER_FORM_NO             object
# ...

# %%
columns = ['TRANSACTION_DATE','REPORTER_DEA_NO','BUYER_DEA_NO', 'TRANSACTION_CODE', 'STRENGTH', 'QUANTITY', 'Measure', 'DRUG_CODE', 'NDC_NO','ACTION_INDICATOR', 'Product_Name', 'Combined_Labeler_Name', 'Revised_Company_Name', 'Reporter_family']

# %%
df[columns].head()
# Out:
#    TRANSACTION_DATE REPORTER_DEA_NO BUYER_DEA_NO TRANSACTION_CODE  STRENGTH  \
# 0          12262012       PA0006836    BT3484653                S       NaN
# 1           3112009       PA0021179    BA9740019                S       NaN
# 2          11252008       PA0021179    BH5651155                S       NaN
# 3           6122009       PA0021179    BH5651155                S       NaN
# 4          10022009       PA0021179    BH5651155                S       NaN
#
#    QUANTITY Measure  DRUG_CODE       NDC_NO ACTION_INDICATOR  \
# 0       1.0     TAB       9193    406036301              NaN
# 1       4.0     TAB       9193  12634051400              NaN
# 2      40.0     TAB       9193  12634051471              NaN
# 3      20.0     TAB       9193  12634078371              NaN
# 4      10.0     TAB       9193  12634051471              NaN
#
#                            Product_Name Combined_Labeler_Name  \
# 0  HYDROCODONE BIT/ACETA 10MG/500MG USP            SpecGx LLC
# ...

# %%
df['DATE'] = df['TRANSACTION_DATE'].astype("string")

# %%
df['DATE'] = df['DATE'].str.zfill(8) #making all the dates the same length so it is easier to extract later?
df.head()
# Out:
#   REPORTER_DEA_NO REPORTER_BUS_ACT               REPORTER_NAME  \
# 0       PA0006836      DISTRIBUTOR  ACE SURGICAL SUPPLY CO INC
# 1       PA0021179      DISTRIBUTOR                APOTHECA INC
# 2       PA0021179      DISTRIBUTOR                APOTHECA INC
# 3       PA0021179      DISTRIBUTOR                APOTHECA INC
# 4       PA0021179      DISTRIBUTOR                APOTHECA INC
#
#   REPORTER_ADDL_CO_INFO  REPORTER_ADDRESS1 REPORTER_ADDRESS2 REPORTER_CITY  \
# 0                   NaN  1034 PEARL STREET               NaN      BROCKTON
# 1                   NaN     1622 N 16TH ST               NaN       PHOENIX
# 2                   NaN     1622 N 16TH ST               NaN       PHOENIX
# 3                   NaN     1622 N 16TH ST               NaN       PHOENIX
# 4                   NaN     1622 N 16TH ST               NaN       PHOENIX
#
#   REPORTER_STATE  REPORTER_ZIP REPORTER_COUNTY  ...  \
# 0             MA          2301        PLYMOUTH  ...
# ...

# %%
df = df.drop('MONTH', axis = 1)
df.head()
# Out:
#   REPORTER_DEA_NO REPORTER_BUS_ACT               REPORTER_NAME  \
# 0       PA0006836      DISTRIBUTOR  ACE SURGICAL SUPPLY CO INC
# 1       PA0021179      DISTRIBUTOR                APOTHECA INC
# 2       PA0021179      DISTRIBUTOR                APOTHECA INC
# 3       PA0021179      DISTRIBUTOR                APOTHECA INC
# 4       PA0021179      DISTRIBUTOR                APOTHECA INC
#
#   REPORTER_ADDL_CO_INFO  REPORTER_ADDRESS1 REPORTER_ADDRESS2 REPORTER_CITY  \
# 0                   NaN  1034 PEARL STREET               NaN      BROCKTON
# 1                   NaN     1622 N 16TH ST               NaN       PHOENIX
# 2                   NaN     1622 N 16TH ST               NaN       PHOENIX
# 3                   NaN     1622 N 16TH ST               NaN       PHOENIX
# 4                   NaN     1622 N 16TH ST               NaN       PHOENIX
#
#   REPORTER_STATE  REPORTER_ZIP REPORTER_COUNTY  ...  \
# 0             MA          2301        PLYMOUTH  ...
# ...

# %%
df = df.drop('YEAR', axis = 1)

# %%
df = df.rename(columns={'DATE': 'DATE_STR'})

# %%
df['DATE'] = = pd.to_datetime(df['DATE_STR'], format='%d%m%Y').dt.strftime('%Y-%m-%d')
